# %%
import json

def read_json(path):
    with open(path) as f:
        return json.load(f)

# %%
test_data_path = '/data/CourseProject/data/deepfashion/test_data.json'
test_data = read_json(test_data_path)

# %%
test_data.keys()
# Out:
# dict_keys(['IMAGES', 'CAPTIONS'])

# %%
len(test_data['IMAGES'])
# Out:
# 2538

# %%
len(test_data['CAPTIONS'])
# Out:
# 2538

# %%
test_data['IMAGES'][0]
# Out:
# '../../data/deepfashion/images/WOMEN-Shorts-id_00006003-01_4_full.jpg'

# %%
from PIL import Image

path = '/data/CourseProject/data/deepfashion/images/WOMEN-Jackets_Coats-id_00005611-01_4_full.jpg'

# %%
Image.open(path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x1101>
